# %% [markdown]
# <center> <h1>Example: BiVO$_4$ tetragonal effective mass with hyperbolic fit </h1> </center>

# %%
# add folders with own pseudo-modules
# kind of hacked way of doing this
import sys
sys.path.append("/home/wwwennie/wwwennie@uchicago.edu/bin/effecmass") # change to where module is
sys.path.append("/home/wwwennie/wwwennie@uchicago.edu/bin/") # directory to common.py

# import plotting script functions
from hyperbol_effmass import *
# %matplotlib inline

# %% [markdown]
# ## DFT+U- electron effective mass

# %%
filename="./bands.g-x.up" 
bands = [53] #CB
init = 50
step = 20

run_effmass(filename,bands,init,step,plot=True)
# Out:
# ----> ./bands.g-x.up
# =================== Band 53 =====================
# alpha = hbar^2/(2m*), m* in units of free electron mass m0
# gamma = hyperbolicity, xshift = horiz fit param, c = vert fit param, CBM
#   # pts    alpha [eV*Ang2]    m* [m0]    gamma [1/eV]    xshift [1/Ang]    c [eV]
# -------  -----------------  ---------  --------------  ----------------  --------
#      50           0.43185     8.82245     1.19249e-05         0.0125991   11.0944
#      70           0.570884    6.67382     2.76037e-12         0.025931    11.0944
#      90           0.723742    5.26427     1.40256e-06         0.0395391   11.0945
#     110           0.877017    4.34424     4.39925e-06         0.0523712   11.0944
#     130           1.01031     3.7711      1.21416e-12         0.0633377   11.0943
#     150           1.09256     3.48718     4.30271e-06         0.0703966   11.0942
#     170           1.23338     3.08906     1.32342             0.0716269   11.0936
# ...

# %% [markdown]
# ## DFT+U- hole electron mass

# %%
filename="./bands.g-x.up" 
bands = [52] #VB
init = 100
step = 10
bnds = ([100,50,10,20],[0,0.,-10.,-20.])

run_effmass(filename,bands,init,step,bounds=bnds,iscbm=False,plot=False)
# Out:
# ----> ./bands.g-x.up
# =================== Band 52 =====================
# alpha = hbar^2/(2m*), m* in units of free electron mass m0
# gamma = hyperbolicity, xshift = horiz fit param, c = vert fit param, CBM
#   # pts    alpha [eV*Ang2]    m* [m0]    gamma [1/eV]    xshift [1/Ang]    c [eV]
# -------  -----------------  ---------  --------------  ----------------  --------
#     100           7.14025    0.533591         49.9998          -2.06139   8.96423
#     110           1.00757    3.78134          49.9996          -2.70674   8.54623
#     120           0.380704  10.0077           49.9993           4.33494   8.51545
#     130           4.33004    0.879894         49.9998           2.45768   8.83598
#     140          10.2555     0.371505         45.7334           4.46819  10.2048
#     150          19.4487     0.195899         49.9998           3.34432  10.1551
#     160          24.0924     0.15814          43.3773           4.25411  11.2204
# ...
